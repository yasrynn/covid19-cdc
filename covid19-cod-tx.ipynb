# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# import sys
# import os
import pandas as pd
from pathlib import Path

# %%
cod_df = pd.read_csv(Path.home() / 'Downloads' / 'Weekly_counts_of_death_by_jurisdiction_and_cause_of_death.csv')

# %%
cod_df.h
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d5be2fbb7b9c> in <module>
# ----> 1 cod_df.h
#
# ~/projects/oag-ml-core/oag-ml-core-venv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'h'

# %%
cod_df[cod_df['Cause Subgroup'] == 'Respiratory diseases']
# Out:
#      Jurisdiction Week Ending Date State Abbreviation  Year  Week  \
# 2830        Texas       2015-01-10                 TX  2015     1
# 2831        Texas       2016-01-09                 TX  2016     1
# 2832        Texas       2017-01-07                 TX  2017     1
# 2833        Texas       2018-01-06                 TX  2018     1
# 2834        Texas       2019-01-05                 TX  2019     1
# ...           ...              ...                ...   ...   ...
# 3674        Texas       2016-01-02                 TX  2015    52
# 3675        Texas       2016-12-31                 TX  2016    52
# 3676        Texas       2017-12-30                 TX  2017    52
# 3677        Texas       2018-12-29                 TX  2018    52
# 3678        Texas       2019-12-28                 TX  2019    52
#
#                                    Cause Group  Number of Deaths  \
# 2830         Chronic lower respiratory disease               277
# ...

# %%
mort_df = pd.read_csv(Path.home() / 'Downloads' / 'Influenza_Pneumonia Mortality by State.csv')

# %%
mort_df.shape
# Out:
# (301, 5)

# %%
mort_df.head()
# Out:
#      YEAR STATE  RATE DEATHS                                       URL
# 0  2018.0    AL  21.4   1268     /nchs/pressroom/states/alabama/al.htm
# 1  2018.0    AK  12.1     68      /nchs/pressroom/states/alaska/ak.htm
# 2  2018.0    AZ  12.4   1116     /nchs/pressroom/states/arizona/az.htm
# 3  2018.0    AR  18.0    670    /nchs/pressroom/states/arkansas/ar.htm
# 4  2018.0    CA  15.6   6917  /nchs/pressroom/states/california/ca.htm

# %%
mort_df[mort_df['STATE'] == 'TX']
# Out:
#        YEAR STATE  RATE DEATHS                                     URL
# 42   2018.0    TX  12.9   3516     /nchs/pressroom/states/texas/tx.htm
# 92   2017.0    TX  11.2  2,954  /nchs/pressroom/states/texas/texas.htm
# 142  2016.0    TX  11.1  2,860  /nchs/pressroom/states/texas/texas.htm
# 192  2015.0    TX  13.0  3,214  /nchs/pressroom/states/texas/texas.htm
# 242  2014.0    TX  14.2  3,452  /nchs/pressroom/states/texas/texas.htm
# 292  2005.0    TX  20.5  3,654  /nchs/pressroom/states/texas/texas.htm

# %%
prov_df = pd.read_csv(Path.home() / 'Downloads' / 'Provisional_COVID-19_Death_Counts_by_Week_Ending_Date_and_State.csv')

# %%
prov_df.shape
# Out:
# (1134, 14)

# %%
prov_df.head()
# Out:
#    Data as of  Start week    End Week    Group          State    Indicator  \
# 0  06/26/2020  02/01/2020  02/01/2020  By week  United States  Week-ending
# 1  06/26/2020  02/08/2020  02/08/2020  By week  United States  Week-ending
# 2  06/26/2020  02/15/2020  02/15/2020  By week  United States  Week-ending
# 3  06/26/2020  02/22/2020  02/22/2020  By week  United States  Week-ending
# 4  06/26/2020  02/29/2020  02/29/2020  By week  United States  Week-ending
#
#    COVID-19 Deaths  Total Deaths  Percent of Expected Deaths  \
# 0              1.0       58179.0                        0.98
# 1              1.0       58771.0                        0.98
# 2              0.0       57904.0                        0.98
# 3              5.0       57864.0                        1.00
# 4              5.0       58250.0                        1.01
#
#    Pneumonia Deaths  Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 0            3766.0                            0.0             477.0
# ...

# %%
prov_df[prov_df['State'] == 'Texas']
# Out:
#      Data as of  Start week    End Week    Group  State    Indicator  \
# 945  06/26/2020  02/01/2020  02/01/2020  By week  Texas  Week-ending
# 946  06/26/2020  02/08/2020  02/08/2020  By week  Texas  Week-ending
# 947  06/26/2020  02/15/2020  02/15/2020  By week  Texas  Week-ending
# 948  06/26/2020  02/22/2020  02/22/2020  By week  Texas  Week-ending
# 949  06/26/2020  02/29/2020  02/29/2020  By week  Texas  Week-ending
# 950  06/26/2020  03/07/2020  03/07/2020  By week  Texas  Week-ending
# 951  06/26/2020  03/14/2020  03/14/2020  By week  Texas  Week-ending
# 952  06/26/2020  03/21/2020  03/21/2020  By week  Texas  Week-ending
# 953  06/26/2020  03/28/2020  03/28/2020  By week  Texas  Week-ending
# 954  06/26/2020  04/04/2020  04/04/2020  By week  Texas  Week-ending
# 955  06/26/2020  04/11/2020  04/11/2020  By week  Texas  Week-ending
# 956  06/26/2020  04/18/2020  04/18/2020  By week  Texas  Week-ending
# 957  06/26/2020  04/25/2020  04/25/2020  By week  Texas  Week-ending
# ...

# %%
pd.Series([None])
# Out:
# 0    None
# dtype: object

# %%
prov_df[prov_df.isnull()] = prov_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-0da985e3d292> in <module>
# ----> 1 prov_df[prov_df.isnull()] = prov_df
#
# ~/projects/oag-ml-core/oag-ml-core-venv/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2931
#    2932         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
# -> 2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    2935             self._setitem_array(key, value)
#
# ~/projects/oag-ml-core/oag-ml-core-venv/lib/python3.8/site-packages/pandas/core/frame.py in _setitem_frame(self, key, value)
#    2982             )
#    2983
# -> 2984         self._check_inplace_setting(value)
#    2985         self._check_setitem_copy()
#    2986         self._where(-key, value, inplace=True)
#
# ...

# %%
pd.DataFrame([0], columns=[1])
# Out:
#    1
# 0  0

# %%
test_df = pd.DataFrame([[None], [4]]).join(pd.Series(['asdf'], name=1))

# %%
test_df
# Out:
#      0     1
# 0  NaN  asdf
# 1  4.0   NaN

# %%
test_df[0] = pd.Series([0, 1], dtype='int64')

# %%
test_df
# Out:
#    0    1
# 0  0  1.0
# 1  1  4.0

# %%
test_df[test_df.isnull()] = pd.DataFrame([[0,1.0],[3,4.0]])

# %%
test_df
# Out:
#      0    1
# 0  0.0  1.0
# 1  3.0  4.0

# %%
X_copy = pd.read_csv('/Users/alanbertl/oag/X_copy.csv').set_index('api')
df_nulls = pd.read_csv('/Users/alanbertl/oag/df_nulls.csv').set_index('api')

# %%
X_copy[X_copy.isnull()] = df_nulls

# %%
pd.__version__
# Out:
# '1.0.3'

# %%
X_copy
# Out:
#                 api  ocwv_bottom  ocwv_file_number  ocwv_fluid_bbl_per_ft  \
# 0    33023010860000        14212             26080               4.634712
# 1    33013016740000        18329             22716               2.036863
# 2    33023010850000        18176             26050               4.665337
# 3    33105025330000        15069             22356               4.609995
# 4    33013016510000        12750             22258               4.661590
# ..              ...          ...               ...                    ...
# 443  33105025480000        20600             22495              24.359103
# 444  33061020390000        20120             22461               8.338875
# 445  33105032350000        19593             26623              23.969472
# 446  33061016510000        18603             20260               5.566689
# 447  33061017020000        18625             20542               6.778579
#
#      ocwv_ft_per_stage  ocwv_lateral_length  ocwv_max_treat_press  \
# ...

# %%
df_nulls.shape
# Out:
# (448, 55)

# %%
40.44 / 35.71
# Out:
# 1.1324558947073649

# %%
53.85 / 24
# Out:
# 2.24375

# %%
X_copy.shape
# Out:
# (448, 54)
